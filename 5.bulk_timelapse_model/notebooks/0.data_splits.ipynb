# %%
import itertools
import json
import pathlib

import numpy as np
import pandas as pd

# %%
bulk_data_file_path = pathlib.Path(
    "../../data/CP_scDINO_features/combined_CP_scDINO_norm_fs_aggregated.parquet"
).resolve(strict=True)
whole_image_final_data_file_path = pathlib.Path(
    "../../data/CP_aggregated/endpoints/aggregated_whole_image.parquet"
).resolve(strict=True)
ground_truth_file_path = pathlib.Path(
    "../../1.ground_truth/data/0.ground_truth/ground_truth.csv"
).resolve(strict=True)
data_splits_dir = pathlib.Path("../data_splits/").resolve()
data_splits_dir.mkdir(parents=True, exist_ok=True)

# Load the data
bulk_df = pd.read_parquet(bulk_data_file_path)
ground_truth_df = pd.read_csv(ground_truth_file_path)
whole_image_final_df = pd.read_parquet(whole_image_final_data_file_path)
bulk_df["Metadata_dose"] = bulk_df["Metadata_dose"].astype("float64")
bulk_df["Metadata_Time"] = bulk_df["Metadata_Time"].astype("float64")
# get the final_timepoint only for the bulk data
bulk_df = bulk_df[bulk_df["Metadata_Time"] == bulk_df["Metadata_Time"].max()]
bulk_df.drop(columns=["Metadata_Time"], inplace=True)
bulk_df.head()
# Out:
#      Metadata_Well  Metadata_dose  Metadata_plate  \
# 1450          C-02            0.0               1
# 1451          C-02            0.0               1
# 1452          C-02            0.0               1
# 1453          C-02            0.0               1
# 1454          C-02            0.0               1
#
#       Metadata_number_of_singlecells Metadata_compound Metadata_control  \
# 1450                             174     Staurosporine         negative
# 1451                             174     Staurosporine         negative
# 1452                             174     Staurosporine         negative
# 1453                             174     Staurosporine         negative
# 1454                             174     Staurosporine         negative
#
#      Metadata_ImageNumber Metadata_FOV  Metadata_Cells_Number_Object_Number  \
# 1450                   13         0003                                  3.0
# 1451                   13         0003                                  5.0
# 1452                   13         0003                                  8.0
# 1453                   13         0003                                 11.0
# 1454                   13         0003                                 12.0
#
#       Metadata_Cytoplasm_Parent_Cells  ...  channel_DNA_cls_feature_91_scDINO  \
# 1450                                3  ...                           0.033469
# 1451                                5  ...                           0.033469
# 1452                                8  ...                           0.033469
# 1453                               11  ...                           0.033469
# 1454                               12  ...                           0.033469
#
#       channel_DNA_cls_feature_92_scDINO  channel_DNA_cls_feature_93_scDINO  \
# 1450                            0.06268                           0.357989
# 1451                            0.06268                           0.357989
# 1452                            0.06268                           0.357989
# 1453                            0.06268                           0.357989
# 1454                            0.06268                           0.357989
#
#       channel_DNA_cls_feature_94_scDINO channel_DNA_cls_feature_95_scDINO  \
# 1450                           0.291235                         -0.693899
# 1451                           0.291235                         -0.693899
# 1452                           0.291235                         -0.693899
# 1453                           0.291235                         -0.693899
# 1454                           0.291235                         -0.693899
#
#      channel_DNA_cls_feature_96_scDINO channel_DNA_cls_feature_97_scDINO  \
# 1450                           0.37725                          0.338003
# 1451                           0.37725                          0.338003
# 1452                           0.37725                          0.338003
# 1453                           0.37725                          0.338003
# 1454                           0.37725                          0.338003
#
#      channel_DNA_cls_feature_98_scDINO channel_DNA_cls_feature_99_scDINO  \
# 1450                          0.342171                          0.058405
# 1451                          0.342171                          0.058405
# 1452                          0.342171                          0.058405
# 1453                          0.342171                          0.058405
# 1454                          0.342171                          0.058405
#
#      channel_DNA_cls_feature_9_scDINO
# 1450                        -0.129908
# 1451                        -0.129908
# 1452                        -0.129908
# 1453                        -0.129908
# 1454                        -0.129908
#
# [5 rows x 2424 columns]

# %%
# prepend "Terminal" to all columns in the whole image final dataframe
for col in whole_image_final_df.columns:
    if col == "Metadata_dose":
        continue
    if col == "Metadata_Well":
        continue
    whole_image_final_df.rename(columns={col: "Terminal_" + col}, inplace=True)

# %%
print("Bulk data shape: ", bulk_df.shape)
print("Whole image final data shape: ", whole_image_final_df.shape)
# Out:
# Bulk data shape:  (10467, 2424)
# Whole image final data shape:  (30, 25)

# %%
bulk_df = pd.merge(
    bulk_df,
    ground_truth_df[["Metadata_dose", "apoptosis"]],
    how="left",
    left_on="Metadata_dose",
    right_on="Metadata_dose",
)
gt = bulk_df.pop("apoptosis")
bulk_df.insert(3, "Metadata_apoptosis_ground_truth", gt)

bulk_df = pd.merge(
    bulk_df,
    whole_image_final_df,
    how="left",
    left_on=["Metadata_dose", "Metadata_Well"],
    right_on=["Metadata_dose", "Metadata_Well"],
)
bulk_df.head()
# Out:
#   Metadata_Well  Metadata_dose  Metadata_plate  \
# 0          C-02            0.0               1
# 1          C-02            0.0               1
# 2          C-02            0.0               1
# 3          C-02            0.0               1
# 4          C-02            0.0               1
#
#   Metadata_apoptosis_ground_truth  Metadata_number_of_singlecells  \
# 0                         control                             174
# 1                         control                             174
# 2                         control                             174
# 3                         control                             174
# 4                         control                             174
#
#   Metadata_compound Metadata_control Metadata_ImageNumber Metadata_FOV  \
# 0     Staurosporine         negative                   13         0003
# 1     Staurosporine         negative                   13         0003
# 2     Staurosporine         negative                   13         0003
# 3     Staurosporine         negative                   13         0003
# 4     Staurosporine         negative                   13         0003
#
#    Metadata_Cells_Number_Object_Number  ...  \
# 0                                  3.0  ...
# 1                                  5.0  ...
# 2                                  8.0  ...
# 3                                 11.0  ...
# 4                                 12.0  ...
#
#    Terminal_Texture_DifferenceEntropy_DNA_3_00_256  \
# 0                                         0.670063
# 1                                         0.670063
# 2                                         0.670063
# 3                                         0.670063
# 4                                         0.670063
#
#    Terminal_Texture_DifferenceVariance_AnnexinV_3_02_256  \
# 0                                          -1.416381
# 1                                          -1.416381
# 2                                          -1.416381
# 3                                          -1.416381
# 4                                          -1.416381
#
#    Terminal_Texture_DifferenceVariance_DNA_3_00_256  \
# 0                                         -0.288271
# 1                                         -0.288271
# 2                                         -0.288271
# 3                                         -0.288271
# 4                                         -0.288271
#
#    Terminal_Texture_InfoMeas1_AnnexinV_3_03_256  \
# 0                                      0.776827
# 1                                      0.776827
# 2                                      0.776827
# 3                                      0.776827
# 4                                      0.776827
#
#    Terminal_Texture_InfoMeas1_DNA_3_01_256  \
# 0                                 0.938617
# 1                                 0.938617
# 2                                 0.938617
# 3                                 0.938617
# 4                                 0.938617
#
#   Terminal_Texture_InfoMeas2_AnnexinV_3_03_256  \
# 0                                    -1.208536
# 1                                    -1.208536
# 2                                    -1.208536
# 3                                    -1.208536
# 4                                    -1.208536
#
#   Terminal_Texture_InfoMeas2_DNA_3_00_256  \
# 0                                0.292902
# 1                                0.292902
# 2                                0.292902
# 3                                0.292902
# 4                                0.292902
#
#   Terminal_Texture_InverseDifferenceMoment_AnnexinV_3_00_256  \
# 0                                           1.162458
# 1                                           1.162458
# 2                                           1.162458
# 3                                           1.162458
# 4                                           1.162458
#
#   Terminal_Texture_SumVariance_AnnexinV_3_03_256  \
# 0                                      -0.191628
# 1                                      -0.191628
# 2                                      -0.191628
# 3                                      -0.191628
# 4                                      -0.191628
#
#   Terminal_Texture_SumVariance_DNA_3_02_256
# 0                                  0.117745
# 1                                  0.117745
# 2                                  0.117745
# 3                                  0.117745
# 4                                  0.117745
#
# [5 rows x 2448 columns]

# %%
dose_wells = bulk_df.copy()
dose_wells = dose_wells[["Metadata_dose", "Metadata_Well"]]
dose_wells = dose_wells.drop_duplicates()
dose_wells = dose_wells.reset_index(drop=True)

# %%
# there are 10 doses, with three wells each
# one well is needed for each dose for training
# select one well per dose
test_wells = []
for dose in dose_wells["Metadata_dose"].unique():
    wells = dose_wells[dose_wells["Metadata_dose"] == dose]["Metadata_Well"].tolist()
    selected_well = np.random.choice(wells, 1)[0]
    print(f"Selected well {selected_well} for dose {dose}")
    test_wells.append(str(selected_well))

train_wells = dose_wells[~dose_wells["Metadata_Well"].isin(test_wells)][
    "Metadata_Well"
].tolist()
# Out:
# Selected well C-02 for dose 0.0
# Selected well D-03 for dose 0.61
# Selected well C-04 for dose 1.22
# Selected well D-05 for dose 2.44
# Selected well D-06 for dose 4.88
# Selected well D-07 for dose 9.77
# Selected well C-08 for dose 19.53
# Selected well D-09 for dose 39.06
# Selected well C-10 for dose 78.13
# Selected well D-11 for dose 156.25

# %%
train_df = bulk_df[bulk_df["Metadata_Well"].isin(train_wells)]
test_df = bulk_df[bulk_df["Metadata_Well"].isin(test_wells)]
train_df = train_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)
# write the train and test dataframes to parquet files
train_df_file_path = data_splits_dir / "train.parquet"
train_df.to_parquet(train_df_file_path, index=False)
test_df_file_path = data_splits_dir / "test.parquet"
test_df.to_parquet(test_df_file_path, index=False)

# %%
print("Train data shape: ", train_df.shape)
train_df.head()
# Out:
# Train data shape:  (6814, 2448)
#   Metadata_Well  Metadata_dose  Metadata_plate  \
# 0          C-03           0.61               1
# 1          C-03           0.61               1
# 2          C-03           0.61               1
# 3          C-03           0.61               1
# 4          C-03           0.61               1
#
#   Metadata_apoptosis_ground_truth  Metadata_number_of_singlecells  \
# 0                        negative                             185
# 1                        negative                             185
# 2                        negative                             185
# 3                        negative                             185
# 4                        negative                             185
#
#   Metadata_compound Metadata_control Metadata_ImageNumber Metadata_FOV  \
# 0     Staurosporine             test                   13         0002
# 1     Staurosporine             test                   13         0002
# 2     Staurosporine             test                   13         0002
# 3     Staurosporine             test                   13         0002
# 4     Staurosporine             test                   13         0002
#
#    Metadata_Cells_Number_Object_Number  ...  \
# 0                                  1.0  ...
# 1                                  6.0  ...
# 2                                  9.0  ...
# 3                                 12.0  ...
# 4                                 14.0  ...
#
#    Terminal_Texture_DifferenceEntropy_DNA_3_00_256  \
# 0                                         0.424535
# 1                                         0.424535
# 2                                         0.424535
# 3                                         0.424535
# 4                                         0.424535
#
#    Terminal_Texture_DifferenceVariance_AnnexinV_3_02_256  \
# 0                                           0.357361
# 1                                           0.357361
# 2                                           0.357361
# 3                                           0.357361
# 4                                           0.357361
#
#    Terminal_Texture_DifferenceVariance_DNA_3_00_256  \
# 0                                         -0.701164
# 1                                         -0.701164
# 2                                         -0.701164
# 3                                         -0.701164
# 4                                         -0.701164
#
#    Terminal_Texture_InfoMeas1_AnnexinV_3_03_256  \
# 0                                      0.012743
# 1                                      0.012743
# 2                                      0.012743
# 3                                      0.012743
# 4                                      0.012743
#
#    Terminal_Texture_InfoMeas1_DNA_3_01_256  \
# 0                                  0.76919
# 1                                  0.76919
# 2                                  0.76919
# 3                                  0.76919
# 4                                  0.76919
#
#   Terminal_Texture_InfoMeas2_AnnexinV_3_03_256  \
# 0                                    -0.252766
# 1                                    -0.252766
# 2                                    -0.252766
# 3                                    -0.252766
# 4                                    -0.252766
#
#   Terminal_Texture_InfoMeas2_DNA_3_00_256  \
# 0                                0.186356
# 1                                0.186356
# 2                                0.186356
# 3                                0.186356
# 4                                0.186356
#
#   Terminal_Texture_InverseDifferenceMoment_AnnexinV_3_00_256  \
# 0                                           1.041248
# 1                                           1.041248
# 2                                           1.041248
# 3                                           1.041248
# 4                                           1.041248
#
#   Terminal_Texture_SumVariance_AnnexinV_3_03_256  \
# 0                                      -1.172505
# 1                                      -1.172505
# 2                                      -1.172505
# 3                                      -1.172505
# 4                                      -1.172505
#
#   Terminal_Texture_SumVariance_DNA_3_02_256
# 0                                  0.076896
# 1                                  0.076896
# 2                                  0.076896
# 3                                  0.076896
# 4                                  0.076896
#
# [5 rows x 2448 columns]

# %%
print("Test data shape: ", test_df.shape)
test_df.head()
# Out:
# Test data shape:  (3653, 2448)
#   Metadata_Well  Metadata_dose  Metadata_plate  \
# 0          C-02            0.0               1
# 1          C-02            0.0               1
# 2          C-02            0.0               1
# 3          C-02            0.0               1
# 4          C-02            0.0               1
#
#   Metadata_apoptosis_ground_truth  Metadata_number_of_singlecells  \
# 0                         control                             174
# 1                         control                             174
# 2                         control                             174
# 3                         control                             174
# 4                         control                             174
#
#   Metadata_compound Metadata_control Metadata_ImageNumber Metadata_FOV  \
# 0     Staurosporine         negative                   13         0003
# 1     Staurosporine         negative                   13         0003
# 2     Staurosporine         negative                   13         0003
# 3     Staurosporine         negative                   13         0003
# 4     Staurosporine         negative                   13         0003
#
#    Metadata_Cells_Number_Object_Number  ...  \
# 0                                  3.0  ...
# 1                                  5.0  ...
# 2                                  8.0  ...
# 3                                 11.0  ...
# 4                                 12.0  ...
#
#    Terminal_Texture_DifferenceEntropy_DNA_3_00_256  \
# 0                                         0.670063
# 1                                         0.670063
# 2                                         0.670063
# 3                                         0.670063
# 4                                         0.670063
#
#    Terminal_Texture_DifferenceVariance_AnnexinV_3_02_256  \
# 0                                          -1.416381
# 1                                          -1.416381
# 2                                          -1.416381
# 3                                          -1.416381
# 4                                          -1.416381
#
#    Terminal_Texture_DifferenceVariance_DNA_3_00_256  \
# 0                                         -0.288271
# 1                                         -0.288271
# 2                                         -0.288271
# 3                                         -0.288271
# 4                                         -0.288271
#
#    Terminal_Texture_InfoMeas1_AnnexinV_3_03_256  \
# 0                                      0.776827
# 1                                      0.776827
# 2                                      0.776827
# 3                                      0.776827
# 4                                      0.776827
#
#    Terminal_Texture_InfoMeas1_DNA_3_01_256  \
# 0                                 0.938617
# 1                                 0.938617
# 2                                 0.938617
# 3                                 0.938617
# 4                                 0.938617
#
#   Terminal_Texture_InfoMeas2_AnnexinV_3_03_256  \
# 0                                    -1.208536
# 1                                    -1.208536
# 2                                    -1.208536
# 3                                    -1.208536
# 4                                    -1.208536
#
#   Terminal_Texture_InfoMeas2_DNA_3_00_256  \
# 0                                0.292902
# 1                                0.292902
# 2                                0.292902
# 3                                0.292902
# 4                                0.292902
#
#   Terminal_Texture_InverseDifferenceMoment_AnnexinV_3_00_256  \
# 0                                           1.162458
# 1                                           1.162458
# 2                                           1.162458
# 3                                           1.162458
# 4                                           1.162458
#
#   Terminal_Texture_SumVariance_AnnexinV_3_03_256  \
# 0                                      -0.191628
# 1                                      -0.191628
# 2                                      -0.191628
# 3                                      -0.191628
# 4                                      -0.191628
#
#   Terminal_Texture_SumVariance_DNA_3_02_256
# 0                                  0.117745
# 1                                  0.117745
# 2                                  0.117745
# 3                                  0.117745
# 4                                  0.117745
#
# [5 rows x 2448 columns]

# %%
# make a df with the wells used for training and testing with their respective doses
test_well_df = pd.DataFrame(test_wells, columns=["Metadata_Well"])
train_well_df = pd.DataFrame(train_wells, columns=["Metadata_Well"])
test_well_df["data_split"] = "test"
train_well_df["data_split"] = "train"
train_test_well_df = pd.concat([train_well_df, test_well_df], axis=0)
# save the train test well df to a parquet file
train_test_well_file_path = data_splits_dir / "train_test_wells.parquet"
train_test_well_df.to_parquet(train_test_well_file_path, index=False)
