# %%
import pathlib

import pandas as pd
from copairs import map
from copairs.matching import assign_reference_index

# %%
endpoint_path = pathlib.Path(
    "../../data/CP_feature_select/endpoint_whole_image/feature_selected_whole_image.parquet"
).resolve(strict=True)

map_results_path = pathlib.Path("../data/0.ground_truth/map.parquet").resolve()
map_results_path.parent.mkdir(parents=True, exist_ok=True)

endpoint_df = pd.read_parquet(endpoint_path)
endpoint_df.head()
# Out:
#    Metadata_plate Metadata_compound  Metadata_dose Metadata_control  \
# 0               1     Staurosporine           1.22             test
# 1               1     Staurosporine           1.22             test
# 2               1     Staurosporine           1.22             test
# 3               1     Staurosporine           1.22             test
# 4               1     Staurosporine           2.44             test
#
#   Metadata_Channel Metadata_FOV Metadata_FileLocation Metadata_Time  \
# 0             None         0004                  None          0014
# 1             None         0002                  None          0014
# 2             None         0003                  None          0014
# 3             None         0001                  None          0014
# 4             None         0004                  None          0014
#
#   Metadata_Well Metadata_Z_slice  ...  Texture_Correlation_DNA_3_02_256  \
# 0          C-04             0001  ...                          1.337356
# 1          C-04             0001  ...                          0.139861
# 2          C-04             0001  ...                          0.910705
# 3          C-04             0001  ...                         -0.095736
# 4          E-05             0001  ...                          2.716246
#
#    Texture_DifferenceEntropy_DNA_3_02_256  \
# 0                                0.368165
# 1                                1.193812
# 2                                0.849906
# 3                                0.794491
# 4                                0.178535
#
#    Texture_DifferenceVariance_AnnexinV_3_02_256  \
# 0                                      0.593027
# 1                                      1.668160
# 2                                      0.840446
# 3                                      0.059917
# 4                                     -0.713072
#
#    Texture_DifferenceVariance_DNA_3_00_256  \
# 0                                -0.134154
# 1                                -1.100615
# 2                                -0.660441
# 3                                -0.659922
# 4                                -0.613220
#
#    Texture_InfoMeas1_AnnexinV_3_03_256  Texture_InfoMeas1_DNA_3_01_256  \
# 0                            -1.445089                       -1.062122
# 1                             0.093066                        0.978298
# 2                            -0.424044                       -0.519855
# 3                            -1.294545                        1.519666
# 4                            -0.987307                       -2.790860
#
#    Texture_InfoMeas2_AnnexinV_3_03_256  \
# 0                             0.221441
# 1                            -0.947193
# 2                            -0.109288
# 3                             0.094697
# 4                             0.875835
#
#    Texture_InverseDifferenceMoment_AnnexinV_3_00_256  \
# 0                                           2.019266
# 1                                           1.953388
# 2                                           1.308669
# 3                                           2.002679
# 4                                          -0.011052
#
#    Texture_SumVariance_AnnexinV_3_03_256  Texture_SumVariance_DNA_3_02_256
# 0                              -0.663868                          1.129909
# 1                              -1.935278                          1.637002
# 2                              -0.873052                          1.537121
# 3                              -1.055458                          1.022017
# 4                               0.687659                          1.741973
#
# [5 rows x 30 columns]

# %%
reference_col = "Metadata_reference_index"
df_activity = assign_reference_index(
    endpoint_df,
    "Metadata_dose == 0.0",
    reference_col=reference_col,
    default_value=-1,
)
df_activity.head()
# Out:
#    Metadata_plate Metadata_compound  Metadata_dose Metadata_control  \
# 0               1     Staurosporine           1.22             test
# 1               1     Staurosporine           1.22             test
# 2               1     Staurosporine           1.22             test
# 3               1     Staurosporine           1.22             test
# 4               1     Staurosporine           2.44             test
#
#   Metadata_Channel Metadata_FOV Metadata_FileLocation Metadata_Time  \
# 0             None         0004                  None          0014
# 1             None         0002                  None          0014
# 2             None         0003                  None          0014
# 3             None         0001                  None          0014
# 4             None         0004                  None          0014
#
#   Metadata_Well Metadata_Z_slice  ...  Texture_DifferenceEntropy_DNA_3_02_256  \
# 0          C-04             0001  ...                                0.368165
# 1          C-04             0001  ...                                1.193812
# 2          C-04             0001  ...                                0.849906
# 3          C-04             0001  ...                                0.794491
# 4          E-05             0001  ...                                0.178535
#
#    Texture_DifferenceVariance_AnnexinV_3_02_256  \
# 0                                      0.593027
# 1                                      1.668160
# 2                                      0.840446
# 3                                      0.059917
# 4                                     -0.713072
#
#    Texture_DifferenceVariance_DNA_3_00_256  \
# 0                                -0.134154
# 1                                -1.100615
# 2                                -0.660441
# 3                                -0.659922
# 4                                -0.613220
#
#    Texture_InfoMeas1_AnnexinV_3_03_256  Texture_InfoMeas1_DNA_3_01_256  \
# 0                            -1.445089                       -1.062122
# 1                             0.093066                        0.978298
# 2                            -0.424044                       -0.519855
# 3                            -1.294545                        1.519666
# 4                            -0.987307                       -2.790860
#
#    Texture_InfoMeas2_AnnexinV_3_03_256  \
# 0                             0.221441
# 1                            -0.947193
# 2                            -0.109288
# 3                             0.094697
# 4                             0.875835
#
#    Texture_InverseDifferenceMoment_AnnexinV_3_00_256  \
# 0                                           2.019266
# 1                                           1.953388
# 2                                           1.308669
# 3                                           2.002679
# 4                                          -0.011052
#
#    Texture_SumVariance_AnnexinV_3_03_256  Texture_SumVariance_DNA_3_02_256  \
# 0                              -0.663868                          1.129909
# 1                              -1.935278                          1.637002
# 2                              -0.873052                          1.537121
# 3                              -1.055458                          1.022017
# 4                               0.687659                          1.741973
#
#    Metadata_reference_index
# 0                        -1
# 1                        -1
# 2                        -1
# 3                        -1
# 4                        -1
#
# [5 rows x 31 columns]

# %%
pos_sameby = ["Metadata_dose", reference_col]
pos_diffby = []
neg_sameby = []
neg_diffby = ["Metadata_dose", reference_col]
metadata = df_activity.filter(regex="Metadata")
profiles = df_activity.filter(regex="^(?!Metadata)").values

activity_ap = map.average_precision(
    metadata, profiles, pos_sameby, pos_diffby, neg_sameby, neg_diffby
)

activity_ap = activity_ap.query("Metadata_dose != 0.0")
activity_ap.head()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# /home/lippincm/miniforge3/envs/timelapse_analaysis_env/lib/python3.11/site-packages/copairs/compute.py:401: RuntimeWarning: invalid value encountered in divide
#   ap_scores = np.add.reduceat(pr_k * rel_k_list, cutoffs) / num_pos
#    Metadata_plate Metadata_compound  Metadata_dose Metadata_control  \
# 0               1     Staurosporine           1.22             test
# 1               1     Staurosporine           1.22             test
# 2               1     Staurosporine           1.22             test
# 3               1     Staurosporine           1.22             test
# 4               1     Staurosporine           2.44             test
#
#   Metadata_Channel Metadata_FOV Metadata_FileLocation Metadata_Time  \
# 0             None         0004                  None          0014
# 1             None         0002                  None          0014
# 2             None         0003                  None          0014
# 3             None         0001                  None          0014
# 4             None         0004                  None          0014
#
#   Metadata_Well Metadata_Z_slice  Metadata_reference_index  n_pos_pairs  \
# 0          C-04             0001                        -1           11
# 1          C-04             0001                        -1           11
# 2          C-04             0001                        -1           11
# 3          C-04             0001                        -1           11
# 4          E-05             0001                        -1           10
#
#    n_total_pairs  average_precision
# 0             23           0.765638
# 1             23           0.748889
# 2             23           0.832407
# 3             23           0.745112
# 4             22           0.698853

# %%
activity_map = map.mean_average_precision(
    activity_ap, pos_sameby, null_size=1000000, threshold=0.05, seed=0
)
activity_map.reset_index(inplace=True)
activity_map.to_parquet(map_results_path)
activity_map.head()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
#    Metadata_dose  Metadata_reference_index  mean_average_precision  \
# 0           0.61                        -1                0.622398
# 1           1.22                        -1                0.725479
# 2           2.44                        -1                0.620240
# 3           4.88                        -1                0.802444
# 4           9.77                        -1                0.734733
#
#                                             indices   p_value  \
# 0  [17, 18, 19, 20, 29, 30, 31, 32, 61, 62, 63, 64]  0.214002
# 1      [0, 1, 2, 3, 25, 26, 27, 28, 49, 50, 51, 52]  0.048832
# 2         [4, 5, 6, 33, 34, 35, 36, 73, 74, 75, 76]  0.182856
# 3  [13, 14, 15, 16, 41, 42, 43, 44, 57, 58, 59, 60]  0.009751
# 4  [21, 22, 23, 24, 65, 66, 67, 68, 85, 86, 87, 88]  0.041317
#
#    corrected_p_value  below_p  below_corrected_p
# 0           0.214002    False              False
# 1           0.062784     True              False
# 2           0.205713    False              False
# 3           0.017552     True               True
# 4           0.061975     True              False
